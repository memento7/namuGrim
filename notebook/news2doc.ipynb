# %%
from __future__ import absolute_import
from __future__ import print_function
from __future__ import division

# %%
import numpy as np
import pandas as pd
#import tensorflow as tf
import matplotlib.pyplot as plt
import json
import re
import pickle

# %%
import collections
import math
import os
import random
import zipfile

# %% [markdown]
# # naver News Content

# %%
contents = pd.read_csv('../../newsCraw/data/newsContents.csv')

# %%
print (contents.shape)
contents.head(3)
# Out:
# (8041759, 3)
#                                                 href actor  \
# 0  http://news.naver.com/main/read.nhn?mode=LSD&m...   BoA
# 1  http://news.naver.com/main/read.nhn?mode=LSD&m...   BoA
# 2  http://news.naver.com/main/read.nhn?mode=LSD&m...   BoA
#
#                                              content
# 0  - FRB 유동성 공급에 4개 중앙銀 동참 - `슈퍼펀드` 조성에 日 금융권 지원할...
# 1  - BOA 최고경영자 경고[이데일리 권소현기자] 뱅크 오브 아메리카(BOA)의 켄 ...
# 2  - 국제신용등급 어드바이저로 골드만삭스·BOA 선정- 2억불 외화채권 발행 추진…미...

# %% [markdown]
# # Tokenize

# %%
from konlpy.tag import Twitter
tagger = Twitter()
def tokenize(content):
    if content != content: return ''
    return [ word for word, tag in tagger.pos(content) if tag == 'Noun']

# %%
filename = 'check.json'
from os.path import isfile
def load():
    idx = 0
    if isfile(filename):
        with open(filename, 'r') as f:
            ldx = json.load(f)
        idx = int(ldx['idx'])
    return idx

def save(idx):
    print('save ' + str(idx))
    ldx = {}
    ldx['idx'] = str(idx)
    with open(filename, 'w') as f:
        json.dump(ldx, f)

# %%
step = 10000
l, _ = contents.shape
idx = load()

# %%
for i in range(idx, l, step):
    print (i,step)
    frame = contents.iloc[i:i+step]
    print (frame.shape)
    with open('../../newsCraw/data/newsContents.txt', 'a') as f:
        for idx, content in frame.iterrows():
            f.write(" ".join(tokenize(content.content)))
    save (i)
# Out:
# 0 10000
# (10000, 3)
# save 0
# 10000 10000
# (10000, 3)
# save 10000
# 20000 10000
# (10000, 3)
# save 20000
# 30000 10000
# (10000, 3)
# save 30000
# 40000 10000
# (10000, 3)
# save 40000
# 50000 10000
# (10000, 3)
# save 50000
# 60000 10000
# (10000, 3)
# save 60000
# 70000 10000
# (10000, 3)
# save 70000
# 80000 10000
# (10000, 3)
# save 80000
# 90000 10000
# (10000, 3)
# save 90000
# 100000 10000
# (10000, 3)
# save 100000
# 110000 10000
# (10000, 3)
# save 110000
# 120000 10000
# (10000, 3)
# save 120000
# 130000 10000
# (10000, 3)
# save 130000
# 140000 10000
# (10000, 3)
# save 140000
# 150000 10000
# (10000, 3)
# save 150000
# 160000 10000
# (10000, 3)
# save 160000
# 170000 10000
# (10000, 3)
# save 170000
# 180000 10000
# (10000, 3)
# save 180000
# 190000 10000
# (10000, 3)
# save 190000
# 200000 10000
# (10000, 3)
# save 200000
# 210000 10000
# (10000, 3)
# save 210000
# 220000 10000
# (10000, 3)
# save 220000
# 230000 10000
# (10000, 3)
# save 230000
# 240000 10000
# (10000, 3)
# save 240000
# 250000 10000
# (10000, 3)
# save 250000
# 260000 10000
# (10000, 3)
# save 260000
# 270000 10000
# (10000, 3)
# save 270000
# 280000 10000
# (10000, 3)
# save 280000
# 290000 10000
# (10000, 3)
# save 290000
# 300000 10000
# (10000, 3)
# save 300000
# 310000 10000
# (10000, 3)
# save 310000
# 320000 10000
# (10000, 3)
# save 320000
# 330000 10000
# (10000, 3)
# save 330000
# 340000 10000
# (10000, 3)
# save 340000
# 350000 10000
# (10000, 3)
# save 350000
# 360000 10000
# (10000, 3)
# save 360000
# 370000 10000
# (10000, 3)
# save 370000
# 380000 10000
# (10000, 3)
# save 380000
# 390000 10000
# (10000, 3)
# save 390000
# 400000 10000
# (10000, 3)
# save 400000
# 410000 10000
# (10000, 3)
# save 410000
# 420000 10000
# (10000, 3)
# save 420000
# 430000 10000
# (10000, 3)
# save 430000
# 440000 10000
# (10000, 3)
# save 440000
# 450000 10000
# (10000, 3)
# save 450000
# 460000 10000
# (10000, 3)
# save 460000
# 470000 10000
# (10000, 3)
# save 470000
# 480000 10000
# (10000, 3)
# save 480000
# 490000 10000
# (10000, 3)
# save 490000
# 500000 10000
# (10000, 3)
# save 500000
# 510000 10000
# (10000, 3)
# save 510000
# 520000 10000
# (10000, 3)
# save 520000
# 530000 10000
# (10000, 3)
# save 530000
# 540000 10000
# (10000, 3)
# save 540000
# 550000 10000
# (10000, 3)
# save 550000
# 560000 10000
# (10000, 3)
# save 560000
# 570000 10000
# (10000, 3)
# save 570000
# 580000 10000
# (10000, 3)
# save 580000
# 590000 10000
# (10000, 3)
# save 590000
# 600000 10000
# (10000, 3)
# save 600000
# 610000 10000
# (10000, 3)
# save 610000
# 620000 10000
# (10000, 3)
# save 620000
# 630000 10000
# (10000, 3)
# save 630000
# 640000 10000
# (10000, 3)
# save 640000
# 650000 10000
# (10000, 3)
# save 650000
# 660000 10000
# (10000, 3)
# save 660000
# 670000 10000
# (10000, 3)
# save 670000
# 680000 10000
# (10000, 3)
# save 680000
# 690000 10000
# (10000, 3)
# save 690000
# 700000 10000
# (10000, 3)
# save 700000
# 710000 10000
# (10000, 3)
# save 710000
# 720000 10000
# (10000, 3)
# save 720000
# 730000 10000
# (10000, 3)
# save 730000
# 740000 10000
# (10000, 3)
# save 740000
# 750000 10000
# (10000, 3)
# save 750000
# 760000 10000
# (10000, 3)
# save 760000
# 770000 10000
# (10000, 3)
# save 770000
# 780000 10000
# (10000, 3)
# save 780000
# 790000 10000
# (10000, 3)
# save 790000
# 800000 10000
# (10000, 3)
# save 800000
# 810000 10000
# (10000, 3)
# save 810000
# 820000 10000
# (10000, 3)
# save 820000
# 830000 10000
# (10000, 3)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-4e9a79acfae9> in <module>()
#       5     with open('../../newsCraw/data/newsContents.txt', 'a') as f:
#       6         for idx, content in frame.iterrows():
# ----> 7             f.write(" ".join(tokenize(content.content)))
#       8     save (i)
#
# <ipython-input-6-2c158f28a849> in tokenize(content)
#       3 def tokenize(content):
#       4     if content != content: return ''
# ----> 5     return [ word for word, tag in tagger.pos(content) if tag == 'Noun']
#
# /usr/local/lib/python3.5/dist-packages/konlpy/tag/_twitter.py in pos(self, phrase, norm, stem)
#      49                     phrase,
#      50                     jpype.java.lang.Boolean(norm),
# ---> 51                     jpype.java.lang.Boolean(stem)).toArray()
#      52         return [tuple(t.rsplit('/', 1)) for t in tokens]
#      53
#
# /usr/local/lib/python3.5/dist-packages/JPype1-0.6.2-py3.5-linux-x86_64.egg/jpype/_jclass.py in _getClassFor(javaClass)
#      58
#      59
# ---> 60 def _getClassFor(javaClass):
#      61     name = javaClass.getName()
#      62     if name in _CLASSES:
#
# KeyboardInterrupt:
